# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from sklearn.model_selection import train_test_split

# %%
class TwoLayerNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(TwoLayerNet, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()  # activation function
        self.fc2 = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        return out

# %%
def preprocess_data(X, y):
    X = (X - np.mean(X)) / np.std(X)  # standardize X
    y = y.reshape(-1, 1)  # reshape y to 2D array
    return X, y

# %%
def init_weights(model, method='small_random'):
    if method == 'small_random':
        for param in model.parameters():
            nn.init.normal_(param, mean=0, std=0.01)
    elif method == 'xavier':
        for param in model.parameters():
            if len(param.shape) > 1:
                nn.init.xavier_uniform_(param)
    elif method == 'kaiming':
        for param in model.parameters():
            if len(param.shape) > 1:
                nn.init.kaiming_uniform_(param, nonlinearity='relu')

# %%
def train_model(X_train, y_train, X_val, y_val, input_size, hidden_size, num_classes, activation_fn, init_method, reg_lambda, optimizer, learning_rate, num_epochs, hidden_nodes, lr_decay_schedule):
    model = TwoLayerNet(input_size, hidden_size, num_classes)
    init_weights(model, init_method)

    criterion = nn.CrossEntropyLoss()  # use cross-entropy loss for classification
    if reg_lambda > 0:
        l2_reg = 0.0
        for param in model.parameters():
            l2_reg += torch.norm(param)
        criterion = nn.CrossEntropyLoss() + reg_lambda * l2_reg

    if optimizer == 'SGD':
        optimizer = optim.SGD(model.parameters(), lr=learning_rate)
    elif optimizer == 'momentum':
        optimizer = optim.SGD(model.parameters(),
                              lr=learning_rate, momentum=0.9)
    elif optimizer == 'Adam':
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    train_losses = []
    val_losses = []
    best_val_loss = float('inf')
    best_model = None
    for epoch in range(num_epochs):
        # learning rate decay schedule
        if lr_decay_schedule == 'cosine':
            lr = learning_rate * 0.5 * (1 + np.cos(epoch / num_epochs * np.pi))
        else:
            lr = learning_rate

        # train
        model.train()
        optimizer.zero_grad()
        inputs = torch.from_numpy(X_train).float()

# %%
import torchvision.datasets as datasets
import torchvision.transforms as transforms

# Define data transforms to normalize the data
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# Download the training and test sets
trainset = datasets.FashionMNIST(root='../data', train=True, download=False, transform=transform)
testset = datasets.FashionMNIST(root='../data', train=False, download=False, transform=transform)

# Split the training set into training and validation sets
trainset, valset = train_test_split(trainset, test_size=0.2, random_state=42)

# Create data loaders to load the data in batches
trainloader = torch.utils.data.DataLoader(trainset, batch_size=32, shuffle=True)
valloader = torch.utils.data.DataLoader(valset, batch_size=32, shuffle=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=32, shuffle=True)

# %%
# Set device to use (GPU or CPU)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Define hyperparameters
input_size = 784 # 28x28
hidden_size = 8
output_size = 10
learning_rate = 0.1
num_epochs = 100

# Create model, loss function, and optimizer
model = TwoLayerNet(input_size, hidden_size, output_size).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

# Train the model
for epoch in range(num_epochs):
    train_loss = 0.0
    train_correct = 0
    model.train()
    for images, labels in trainloader:
        images = images.view(-1, input_size).to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * images.size(0)
        _, predicted = torch.max(outputs.data, 1)
        train_correct += (predicted == labels).sum().item()
    train_loss /= len(trainloader.dataset)
    train_accuracy = 100. * train_correct / len(trainloader.dataset)

    # Validate the model
    val_loss = 0.0
    val_correct = 0
    model.eval()
    with torch.no_grad():
        for images, labels in valloader:
            images = images.view(-1, input_size).to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item() * images.size(0)
            _, predicted = torch.max(outputs.data, 1)
            val_correct += (predicted == labels).sum().item()
        val_loss /= len(valloader.dataset)
        val_accuracy = 100. * val_correct / len(valloader.dataset)

    # Print epoch statistics
    print('Epoch [{}/{}], Train Loss: {:.4f}, Train Accuracy: {:.2f}%, Val Loss: {:.4f}, Val Accuracy: {:.2f}%'
          .format(epoch+1, num_epochs, train_loss, train_accuracy, val_loss, val_accuracy))
# Out:
# Epoch [1/100], Train Loss: 0.6635, Train Accuracy: 75.88%, Val Loss: 0.5548, Val Accuracy: 80.07%
# Epoch [2/100], Train Loss: 0.5400, Train Accuracy: 80.73%, Val Loss: 0.5710, Val Accuracy: 75.97%
# Epoch [3/100], Train Loss: 0.5135, Train Accuracy: 81.57%, Val Loss: 0.6917, Val Accuracy: 75.38%
# Epoch [4/100], Train Loss: 0.4963, Train Accuracy: 82.31%, Val Loss: 0.4804, Val Accuracy: 83.14%
# Epoch [5/100], Train Loss: 0.4719, Train Accuracy: 83.04%, Val Loss: 0.5111, Val Accuracy: 82.27%
# Epoch [6/100], Train Loss: 0.4633, Train Accuracy: 83.42%, Val Loss: 0.4871, Val Accuracy: 83.15%
# Epoch [7/100], Train Loss: 0.4521, Train Accuracy: 83.78%, Val Loss: 0.4734, Val Accuracy: 83.53%
# Epoch [8/100], Train Loss: 0.4458, Train Accuracy: 83.91%, Val Loss: 0.4886, Val Accuracy: 83.31%
# Epoch [9/100], Train Loss: 0.4415, Train Accuracy: 84.23%, Val Loss: 0.4668, Val Accuracy: 83.58%
# Epoch [10/100], Train Loss: 0.4376, Train Accuracy: 84.42%, Val Loss: 0.4952, Val Accuracy: 82.27%
# Epoch [11/100], Train Loss: 0.4321, Train Accuracy: 84.42%, Val Loss: 0.4917, Val Accuracy: 83.08%
# Epoch [12/100], Train Loss: 0.4281, Train Accuracy: 84.50%, Val Loss: 0.4658, Val Accuracy: 83.98%
# Epoch [13/100], Train Loss: 0.4269, Train Accuracy: 84.65%, Val Loss: 0.4635, Val Accuracy: 83.42%
# Epoch [14/100], Train Loss: 0.4232, Train Accuracy: 84.82%, Val Loss: 0.4984, Val Accuracy: 82.12%
# Epoch [15/100], Train Loss: 0.4206, Train Accuracy: 84.75%, Val Loss: 0.4567, Val Accuracy: 84.28%
# Epoch [16/100], Train Loss: 0.4181, Train Accuracy: 84.85%, Val Loss: 0.4585, Val Accuracy: 84.18%
# Epoch [17/100], Train Loss: 0.4153, Train Accuracy: 84.97%, Val Loss: 0.5124, Val Accuracy: 82.12%
# Epoch [18/100], Train Loss: 0.4131, Train Accuracy: 84.99%, Val Loss: 0.4871, Val Accuracy: 83.26%
# Epoch [19/100], Train Loss: 0.4124, Train Accuracy: 85.14%, Val Loss: 0.4607, Val Accuracy: 83.85%
# Epoch [20/100], Train Loss: 0.4101, Train Accuracy: 85.23%, Val Loss: 0.4733, Val Accuracy: 83.90%
# Epoch [21/100], Train Loss: 0.4080, Train Accuracy: 85.21%, Val Loss: 0.4978, Val Accuracy: 82.59%
# Epoch [22/100], Train Loss: 0.4099, Train Accuracy: 85.23%, Val Loss: 0.4553, Val Accuracy: 84.56%
# Epoch [23/100], Train Loss: 0.4048, Train Accuracy: 85.33%, Val Loss: 0.4373, Val Accuracy: 84.73%
# Epoch [24/100], Train Loss: 0.4043, Train Accuracy: 85.46%, Val Loss: 0.4814, Val Accuracy: 83.57%
# Epoch [25/100], Train Loss: 0.4051, Train Accuracy: 85.17%, Val Loss: 0.4759, Val Accuracy: 84.03%
# Epoch [26/100], Train Loss: 0.4053, Train Accuracy: 85.34%, Val Loss: 0.4542, Val Accuracy: 83.91%
# Epoch [27/100], Train Loss: 0.4007, Train Accuracy: 85.39%, Val Loss: 0.4676, Val Accuracy: 83.97%
# Epoch [28/100], Train Loss: 0.4030, Train Accuracy: 85.28%, Val Loss: 0.4523, Val Accuracy: 84.18%
# Epoch [29/100], Train Loss: 0.4000, Train Accuracy: 85.49%, Val Loss: 0.4874, Val Accuracy: 83.38%
# Epoch [30/100], Train Loss: 0.3995, Train Accuracy: 85.50%, Val Loss: 0.5012, Val Accuracy: 83.01%
# Epoch [31/100], Train Loss: 0.3974, Train Accuracy: 85.52%, Val Loss: 0.5380, Val Accuracy: 81.86%
# Epoch [32/100], Train Loss: 0.3987, Train Accuracy: 85.42%, Val Loss: 0.4652, Val Accuracy: 84.05%
# Epoch [33/100], Train Loss: 0.3977, Train Accuracy: 85.47%, Val Loss: 0.5292, Val Accuracy: 81.88%
# Epoch [34/100], Train Loss: 0.3952, Train Accuracy: 85.63%, Val Loss: 0.4636, Val Accuracy: 84.42%
# Epoch [35/100], Train Loss: 0.3948, Train Accuracy: 85.60%, Val Loss: 0.4845, Val Accuracy: 83.58%
# Epoch [36/100], Train Loss: 0.3923, Train Accuracy: 85.65%, Val Loss: 0.4630, Val Accuracy: 83.80%
# Epoch [37/100], Train Loss: 0.3918, Train Accuracy: 85.68%, Val Loss: 0.4348, Val Accuracy: 85.06%
# Epoch [38/100], Train Loss: 0.3919, Train Accuracy: 85.77%, Val Loss: 0.4544, Val Accuracy: 84.62%
# Epoch [39/100], Train Loss: 0.3892, Train Accuracy: 85.85%, Val Loss: 0.5051, Val Accuracy: 83.18%
# Epoch [40/100], Train Loss: 0.3891, Train Accuracy: 85.88%, Val Loss: 0.4468, Val Accuracy: 84.72%
# Epoch [41/100], Train Loss: 0.3888, Train Accuracy: 85.99%, Val Loss: 0.4806, Val Accuracy: 83.48%
# Epoch [42/100], Train Loss: 0.3899, Train Accuracy: 85.88%, Val Loss: 0.5050, Val Accuracy: 83.13%
# Epoch [43/100], Train Loss: 0.3908, Train Accuracy: 85.85%, Val Loss: 0.5073, Val Accuracy: 82.56%
# Epoch [44/100], Train Loss: 0.3899, Train Accuracy: 85.92%, Val Loss: 0.6654, Val Accuracy: 78.83%
# Epoch [45/100], Train Loss: 0.3870, Train Accuracy: 85.84%, Val Loss: 0.4758, Val Accuracy: 83.58%
# Epoch [46/100], Train Loss: 0.3865, Train Accuracy: 85.99%, Val Loss: 0.4511, Val Accuracy: 84.54%
# Epoch [47/100], Train Loss: 0.3869, Train Accuracy: 85.74%, Val Loss: 0.4690, Val Accuracy: 83.82%
# Epoch [48/100], Train Loss: 0.3869, Train Accuracy: 85.92%, Val Loss: 0.4849, Val Accuracy: 83.37%
# Epoch [49/100], Train Loss: 0.3838, Train Accuracy: 86.05%, Val Loss: 0.4669, Val Accuracy: 84.38%
# Epoch [50/100], Train Loss: 0.3820, Train Accuracy: 86.06%, Val Loss: 0.4598, Val Accuracy: 84.17%
# Epoch [51/100], Train Loss: 0.3827, Train Accuracy: 86.05%, Val Loss: 0.4846, Val Accuracy: 83.87%
# Epoch [52/100], Train Loss: 0.3809, Train Accuracy: 86.16%, Val Loss: 0.5153, Val Accuracy: 82.62%
# Epoch [53/100], Train Loss: 0.3850, Train Accuracy: 86.01%, Val Loss: 0.4593, Val Accuracy: 84.26%
# Epoch [54/100], Train Loss: 0.3828, Train Accuracy: 86.10%, Val Loss: 0.4625, Val Accuracy: 84.59%
# Epoch [55/100], Train Loss: 0.3865, Train Accuracy: 85.97%, Val Loss: 0.4513, Val Accuracy: 84.91%
# Epoch [56/100], Train Loss: 0.3791, Train Accuracy: 86.16%, Val Loss: 0.4842, Val Accuracy: 83.93%
# Epoch [57/100], Train Loss: 0.3826, Train Accuracy: 86.12%, Val Loss: 0.5014, Val Accuracy: 83.22%
# Epoch [58/100], Train Loss: 0.3816, Train Accuracy: 86.22%, Val Loss: 0.4747, Val Accuracy: 83.62%
# Epoch [59/100], Train Loss: 0.3790, Train Accuracy: 86.28%, Val Loss: 0.5126, Val Accuracy: 82.78%
# Epoch [60/100], Train Loss: 0.3784, Train Accuracy: 86.10%, Val Loss: 0.4705, Val Accuracy: 83.88%
# Epoch [61/100], Train Loss: 0.3790, Train Accuracy: 86.24%, Val Loss: 0.4971, Val Accuracy: 83.29%
# Epoch [62/100], Train Loss: 0.3800, Train Accuracy: 86.16%, Val Loss: 0.4680, Val Accuracy: 84.07%
# Epoch [63/100], Train Loss: 0.3771, Train Accuracy: 86.23%, Val Loss: 0.4923, Val Accuracy: 83.01%
# Epoch [64/100], Train Loss: 0.3786, Train Accuracy: 86.29%, Val Loss: 0.4791, Val Accuracy: 83.97%
# Epoch [65/100], Train Loss: 0.3782, Train Accuracy: 86.10%, Val Loss: 0.5251, Val Accuracy: 82.30%
# Epoch [66/100], Train Loss: 0.3785, Train Accuracy: 86.13%, Val Loss: 0.5081, Val Accuracy: 83.03%
# Epoch [67/100], Train Loss: 0.3772, Train Accuracy: 86.34%, Val Loss: 0.4861, Val Accuracy: 83.63%
# Epoch [68/100], Train Loss: 0.3762, Train Accuracy: 86.26%, Val Loss: 0.4500, Val Accuracy: 84.98%
# Epoch [69/100], Train Loss: 0.3765, Train Accuracy: 86.34%, Val Loss: 0.4867, Val Accuracy: 84.08%
# Epoch [70/100], Train Loss: 0.3771, Train Accuracy: 86.33%, Val Loss: 0.4903, Val Accuracy: 84.20%
# Epoch [71/100], Train Loss: 0.3741, Train Accuracy: 86.26%, Val Loss: 0.4511, Val Accuracy: 84.87%
# Epoch [72/100], Train Loss: 0.3759, Train Accuracy: 86.32%, Val Loss: 0.5272, Val Accuracy: 83.39%
# Epoch [73/100], Train Loss: 0.3749, Train Accuracy: 86.34%, Val Loss: 0.4801, Val Accuracy: 83.85%
# Epoch [74/100], Train Loss: 0.3745, Train Accuracy: 86.40%, Val Loss: 0.4925, Val Accuracy: 83.29%
# Epoch [75/100], Train Loss: 0.3759, Train Accuracy: 86.25%, Val Loss: 0.4619, Val Accuracy: 84.31%
# Epoch [76/100], Train Loss: 0.3754, Train Accuracy: 86.25%, Val Loss: 0.4829, Val Accuracy: 83.55%
# Epoch [77/100], Train Loss: 0.3737, Train Accuracy: 86.42%, Val Loss: 0.4847, Val Accuracy: 83.67%
# Epoch [78/100], Train Loss: 0.3727, Train Accuracy: 86.56%, Val Loss: 0.4762, Val Accuracy: 84.19%
# Epoch [79/100], Train Loss: 0.3736, Train Accuracy: 86.40%, Val Loss: 0.4697, Val Accuracy: 83.82%
# Epoch [80/100], Train Loss: 0.3724, Train Accuracy: 86.38%, Val Loss: 0.4963, Val Accuracy: 83.92%
# Epoch [81/100], Train Loss: 0.3720, Train Accuracy: 86.49%, Val Loss: 0.4796, Val Accuracy: 83.98%
# Epoch [82/100], Train Loss: 0.3766, Train Accuracy: 86.22%, Val Loss: 0.4650, Val Accuracy: 84.35%
# Epoch [83/100], Train Loss: 0.3734, Train Accuracy: 86.34%, Val Loss: 0.4746, Val Accuracy: 84.21%
# Epoch [84/100], Train Loss: 0.3736, Train Accuracy: 86.27%, Val Loss: 0.4682, Val Accuracy: 84.04%
# Epoch [85/100], Train Loss: 0.3697, Train Accuracy: 86.37%, Val Loss: 0.4618, Val Accuracy: 84.57%
# Epoch [86/100], Train Loss: 0.3730, Train Accuracy: 86.46%, Val Loss: 0.4919, Val Accuracy: 84.03%
# Epoch [87/100], Train Loss: 0.3702, Train Accuracy: 86.47%, Val Loss: 0.4744, Val Accuracy: 84.20%
# Epoch [88/100], Train Loss: 0.3715, Train Accuracy: 86.45%, Val Loss: 0.4633, Val Accuracy: 84.68%
# Epoch [89/100], Train Loss: 0.3693, Train Accuracy: 86.28%, Val Loss: 0.5352, Val Accuracy: 82.83%
# Epoch [90/100], Train Loss: 0.3676, Train Accuracy: 86.59%, Val Loss: 0.4700, Val Accuracy: 84.66%
# Epoch [91/100], Train Loss: 0.3715, Train Accuracy: 86.46%, Val Loss: 0.5031, Val Accuracy: 83.45%
# Epoch [92/100], Train Loss: 0.3708, Train Accuracy: 86.33%, Val Loss: 0.4987, Val Accuracy: 83.14%
# Epoch [93/100], Train Loss: 0.3668, Train Accuracy: 86.54%, Val Loss: 0.4837, Val Accuracy: 83.92%
# Epoch [94/100], Train Loss: 0.3683, Train Accuracy: 86.54%, Val Loss: 0.4837, Val Accuracy: 84.28%
# Epoch [95/100], Train Loss: 0.3692, Train Accuracy: 86.39%, Val Loss: 0.5014, Val Accuracy: 83.62%
# Epoch [96/100], Train Loss: 0.3703, Train Accuracy: 86.41%, Val Loss: 0.4760, Val Accuracy: 84.06%
# Epoch [97/100], Train Loss: 0.3725, Train Accuracy: 86.30%, Val Loss: 0.4914, Val Accuracy: 83.58%
# Epoch [98/100], Train Loss: 0.3687, Train Accuracy: 86.53%, Val Loss: 0.4947, Val Accuracy: 83.91%
# Epoch [99/100], Train Loss: 0.3687, Train Accuracy: 86.43%, Val Loss: 0.4798, Val Accuracy: 84.00%
# Epoch [100/100], Train Loss: 0.3648, Train Accuracy: 86.79%, Val Loss: 0.4844, Val Accuracy: 83.92%
